# %%
from textgenrnn import textgenrnn
import os

os.chdir('C:/Users/rjsai/Dropbox/Data Science/Just-R-Things/DeepLearning')
# Out:
# C:\Users\rjsai\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
textgen = textgenrnn(
   weights_path = 'jim_bot_weights.hdf5',
   vocab_path = 'jim_bot_vocab.json',
   config_path = 'jim_bot_config.json'
 )

# %%
textgen.generate(100, temperature = .5)
# Out:
# what was that . . . p
#
# ok . so , we ' re going through all the wedding plans and , boy , it ' s stupid . k
#
# i ' m really too tired to do this .
#
# okay , i ' ll just go get the company .
#
# right ? so . . . i am going to make a toast . so it ' s for me .
#
# wow , that ' s weird . oh , dollar for a stapler , that ' s pretty good .
#
# yeah , i ' m aware of that . but he ' s also being super other time i ' m going to be up him yourself .
#
# let me call you right .
#
# no , it ' s not , no . it ' s not , no . but my god , i did let you go to the singer .
#
# you ' re not having sex .
#
# okay , i ' m sorry . i ' m really sorry . it ' s my question , you know .
#
# no , we definitely can talk about it .
#
# oh , i don ' t know .
#
# oh , it ' s just advice . what advice sounds like i can .
#
# you know what ? let ' s go . we got to the guy .
#
# yeah , i ' m definitely gonna go alone .
#
# yeah . yeah , yeah , totally . that ' s an day .
#
# ...
